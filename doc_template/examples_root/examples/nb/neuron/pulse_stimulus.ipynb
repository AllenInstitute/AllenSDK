# %% [markdown]
# Download this file in .ipynb format <a href='pulse_stimulus.ipynb'>here</a>.

# %%
# based on allensdk.model.biophysical.biophysical_perisomatic.runner

# These will be useful for accessing and configuring the downloaded model
from allensdk.model.biophys_sim.config import Config
from allensdk.model.biophysical.utils import Utils

# not using NwbDataSet
# from allensdk.core.nwb_data_set import NwbDataSet

# We'll save results to a simple text file instead
from allensdk.core.dat_utilities import DatUtilities

# %%
from allensdk.api.queries.biophysical_api import BiophysicalApi

neuronal_model_id = 472451419    # get this from the web site
#neuronal_model_id = 480361288
model_directory = '.'

bp = BiophysicalApi('http://api.brain-map.org')
bp.cache_stimulus = False # don't want to download the large stimulus NWB file
bp.cache_data(neuronal_model_id, working_directory=model_directory)
# Out:
# 2019-05-20 15:46:34,434 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491459173
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491459173
# 2019-05-20 15:46:34,460 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/497235805
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/497235805
# 2019-05-20 15:46:34,478 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496607103
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/496607103
# 2019-05-20 15:46:34,494 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337070
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337070
# 2019-05-20 15:46:34,507 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337293
# 2019-05-20 15:46:34,525 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337225
# 2019-05-20 15:46:34,538 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337054
# 2019-05-20 15:46:34,554 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337042
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337042
# 2019-05-20 15:46:34,567 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337050
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337050
# 2019-05-20 15:46:34,585 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337046
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337046
# 2019-05-20 15:46:34,598 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/464138096
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/464138096
# 2019-05-20 15:46:34,614 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337011
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337011
# 2019-05-20 15:46:34,627 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337066
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337066
# 2019-05-20 15:46:34,642 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337015
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337015
# 2019-05-20 15:46:34,656 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491113425
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/491113425
# 2019-05-20 15:46:34,673 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337062
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337062
# 2019-05-20 15:46:34,687 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337007
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337007
# 2019-05-20 15:46:34,704 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337019
# 2019-05-20 15:46:34,716 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337003
# INFO:allensdk.api.api.retrieve_file_over_http:Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/395337003

# %%
import os

os.system('nrnivmodl modfiles')
# Out:
# 0

# %%
description = Config().load('manifest.json')
utils = Utils(description)
h = utils.h
# Out:
# NEURON: Couldn't find: stdgui.hoc
#  near line 0
#  starttime = startsw()
#                       ^
# NEURON: Couldn't find: import3d.hoc
#  near line 0
#  ^
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-13-5eb9f07f61a2> in <module>()
#       1 description = Config().load('manifest.json')
# ----> 2 utils = Utils(description)
#       3 h = utils.h
#
# /home/nicholasc/projects/allensdk/allensdk/model/biophysical/utils.pyc in __init__(self, description)
#      97         self.update_default_cell_hoc(description)
#      98
# ---> 99         super(Utils, self).__init__(description)
#     100         self.stim = None
#     101         self.stim_curr = None
#
# /home/nicholasc/projects/allensdk/allensdk/model/biophys_sim/neuron/hoc_utils.pyc in __init__(self, description)
#      68         self.hoc_files = description.data['neuron'][0]['hoc']
#      69
# ---> 70         self.initialize_hoc()
#      71
#      72     def initialize_hoc(self):
#
# /home/nicholasc/projects/allensdk/allensdk/model/biophys_sim/neuron/hoc_utils.pyc in initialize_hoc(self)
#      85
#      86         if 'v_init' in params:
# ---> 87             h.v_init = params['v_init']
#      88
#      89         if 'dt' in params:
#
# LookupError: 'v_init' is not a defined hoc variable name.

# %%
# configure model
manifest = description.manifest
morphology_path = description.manifest.get_path('MORPHOLOGY')
utils.generate_morphology(morphology_path.encode('ascii', 'ignore'))
utils.load_cell_parameters()

# At this point the cell model has been fully set up in NEURON
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-773ab37e152e> in <module>()
#       2 manifest = description.manifest
#       3 morphology_path = description.manifest.get_path('MORPHOLOGY')
# ----> 4 utils.generate_morphology(morphology_path.encode('ascii', 'ignore'))
#       5 utils.load_cell_parameters()
#       6
#
# NameError: name 'utils' is not defined

# %%
# configure a simple current-clamp stimulus to generate some spikes
stim = h.IClamp(h.soma[0](0.5))
stim.amp = 0.18
stim.delay = 1000.0
stim.dur = 1000.0

h.tstop = 3000.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-174e7698726c> in <module>()
#       1 # configure a simple current-clamp stimulus to generate some spikes
# ----> 2 stim = h.IClamp(h.soma[0](0.5))
#       3 stim.amp = 0.18
#       4 stim.delay = 1000.0
#       5 stim.dur = 1000.0
#
# NameError: name 'h' is not defined

# %%
vec = utils.record_values()

# %%
h.finitialize()
h.run()
# Out:
# 0.0

# %%
# save the result to a simple time and voltage space-separated text file
import numpy

output_path = 'output_voltage.dat'

junction_potential = description.data['fitting'][0]['junction_potential']
mV = 1.0e-3
ms = 1.0e-3

output_data = (numpy.array(vec['v']) - junction_potential) * mV
output_times = numpy.array(vec['t']) * ms

data = numpy.transpose(numpy.vstack((output_times, output_data)))
with open (output_path, "w") as f:
    numpy.savetxt(f, data)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(vec['t'], numpy.array(vec['v']) - junction_potential)
plt.xlabel('time (ms)')
plt.ylabel('membrane potential (mV)')
plt.show()
